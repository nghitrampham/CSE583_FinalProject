# %%
import pandas as pd
from pandas import read_csv
from pandas import DataFrame
from pandas import concat

# %%
data = pd.read_csv("data_air/daily_aqi_by_county_2017.csv")

# %%
data.T
# Out:
#                                 0            1            2            3       \
# State Name                     Alabama      Alabama      Alabama      Alabama
# county Name                    Baldwin      Baldwin      Baldwin      Baldwin
# State Code                           1            1            1            1
# County Code                          3            3            3            3
# Date                        2017-01-01   2017-01-04   2017-01-10   2017-01-13
# AQI                                 21           22           19           30
# Category                          Good         Good         Good         Good
# Defining Parameter               PM2.5        PM2.5        PM2.5        PM2.5
# Defining Site              01-003-0010  01-003-0010  01-003-0010  01-003-0010
# Number of Sites Reporting            1            1            1            1
#
#                                 4            5            6            7       \
# ...

# %%
data["County Code"].nunique()
# Out:
# 166

# %% [markdown]
# # A. Data Preparation

# %%
data["state_county"] = data["county Name"] + "_" +  data["State Name"]
data.head()
# Out:
#   State Name county Name  State Code  County Code        Date  AQI Category  \
# 0    Alabama     Baldwin           1            3  2017-01-01   21     Good
# 1    Alabama     Baldwin           1            3  2017-01-04   22     Good
# 2    Alabama     Baldwin           1            3  2017-01-10   19     Good
# 3    Alabama     Baldwin           1            3  2017-01-13   30     Good
# 4    Alabama     Baldwin           1            3  2017-01-16   16     Good
#
#   Defining Parameter Defining Site  Number of Sites Reporting     state_county
# 0              PM2.5   01-003-0010                          1  Baldwin_Alabama
# 1              PM2.5   01-003-0010                          1  Baldwin_Alabama
# 2              PM2.5   01-003-0010                          1  Baldwin_Alabama
# 3              PM2.5   01-003-0010                          1  Baldwin_Alabama
# 4              PM2.5   01-003-0010                          1  Baldwin_Alabama

# %%
## test for one state 
df_state = data[data["state_county"] == "Baldwin_Alabama"]
df_state["which_date"] = df_state["Date"].apply(lambda x: pd.to_datetime(x))
df_state["current_month"] = df_state["which_date"].apply(lambda x: x.month)
df_state["current_date"] = df_state["which_date"].dt.day
df_state['day_of_week'] = df_state['which_date'].dt.weekday_name
day_df = pd.get_dummies(df_state["day_of_week"], prefix="day")
df_temp = pd.concat([df_state, day_df], axis = 1)
df_feature = df_temp[list(day_df.columns) + ["AQI", "current_date", "current_month", "which_date"]]
df_feature = df_feature.sort_values(by=["which_date"])
df_feature
# Out:
# /Users/NghiTram/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/NghiTram/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/NghiTram/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
# make sure that there is only 1 AQI for each day 
df_state.groupby("Date").count().unstack().reset_index().rename(columns={0: "count"})["count"].max()
# Out:
# 1

# %%
lag_time = 30;
temps = df_feature.sort_values(by=["which_date"])["AQI"]
dataframe = temps
col_name=['AQI']
for lag_index in range(1,lag_time):
    dataframe = concat([temps.shift(lag_index), dataframe], axis=1)
    col_name.append('lag_' + str(lag_index))
dataframe.columns = col_name
df_lag_features = dataframe.iloc[lag_time-1:,:]
df_lag_features.head()
# Out:
#      AQI  lag_1  lag_2  lag_3  lag_4  lag_5  lag_6  lag_7  lag_8  lag_9  \
# 29  21.0   22.0   19.0   30.0   16.0   19.0   29.0   18.0   24.0   14.0
# 30  22.0   19.0   30.0   16.0   19.0   29.0   18.0   24.0   14.0   33.0
# 31  19.0   30.0   16.0   19.0   29.0   18.0   24.0   14.0   33.0   38.0
# 32  30.0   16.0   19.0   29.0   18.0   24.0   14.0   33.0   38.0   30.0
# 33  16.0   19.0   29.0   18.0   24.0   14.0   33.0   38.0   30.0   31.0
#
#      ...    lag_20  lag_21  lag_22  lag_23  lag_24  lag_25  lag_26  lag_27  \
# 29   ...      48.0    49.0    48.0    45.0    47.0    44.0    44.0    45.0
# 30   ...      49.0    48.0    45.0    47.0    44.0    44.0    45.0    47.0
# 31   ...      48.0    45.0    47.0    44.0    44.0    45.0    47.0    32.0
# 32   ...      45.0    47.0    44.0    44.0    45.0    47.0    32.0    31.0
# 33   ...      47.0    44.0    44.0    45.0    47.0    32.0    31.0    29.0
#
#     lag_28  lag_29
# 29    47.0      32
# 30    32.0      31
# 31    31.0      29
# ...

# %%
df_data = (pd.concat([df_lag_features.drop(["AQI"], axis = 1), 
                     df_feature.drop(["which_date"], axis = 1).iloc[lag_time-1:,:]], axis = 1))
print(df_data.shape)
df_data.head()
# Out:
# (241, 39)
#     lag_1  lag_2  lag_3  lag_4  lag_5  lag_6  lag_7  lag_8  lag_9  lag_10  \
# 29   22.0   19.0   30.0   16.0   19.0   29.0   18.0   24.0   14.0    33.0
# 30   19.0   30.0   16.0   19.0   29.0   18.0   24.0   14.0   33.0    38.0
# 31   30.0   16.0   19.0   29.0   18.0   24.0   14.0   33.0   38.0    30.0
# 32   16.0   19.0   29.0   18.0   24.0   14.0   33.0   38.0   30.0    31.0
# 33   19.0   29.0   18.0   24.0   14.0   33.0   38.0   30.0   31.0    22.0
#
#         ...        day_Friday  day_Monday  day_Saturday  day_Sunday  \
# 29      ...                 0           0             0           1
# 30      ...                 0           1             0           0
# 31      ...                 0           0             0           0
# 32      ...                 0           0             0           0
# 33      ...                 1           0             0           0
#
#     day_Thursday  day_Tuesday  day_Wednesday  AQI  current_date  current_month
# ...

# %%
## export csv file 
df_data.to_csv("data_air/Baldwin_Alabama_features_2018.csv", index = False)
df_data.head()
# Out:
#     lag_1  lag_2  lag_3  lag_4  lag_5  lag_6  lag_7  lag_8  lag_9  lag_10  \
# 29   22.0   19.0   30.0   16.0   19.0   29.0   18.0   24.0   14.0    33.0
# 30   19.0   30.0   16.0   19.0   29.0   18.0   24.0   14.0   33.0    38.0
# 31   30.0   16.0   19.0   29.0   18.0   24.0   14.0   33.0   38.0    30.0
# 32   16.0   19.0   29.0   18.0   24.0   14.0   33.0   38.0   30.0    31.0
# 33   19.0   29.0   18.0   24.0   14.0   33.0   38.0   30.0   31.0    22.0
#
#         ...        day_Friday  day_Monday  day_Saturday  day_Sunday  \
# 29      ...                 0           0             0           1
# 30      ...                 0           1             0           0
# 31      ...                 0           0             0           0
# 32      ...                 0           0             0           0
# 33      ...                 1           0             0           0
#
#     day_Thursday  day_Tuesday  day_Wednesday  AQI  current_date  current_month
# ...

# %% [markdown]
# # B. EDA

# %%
df_state[df_state["Date"] == '2018-01-01']
# Out:
#           State Name county Name  State Code  County Code        Date  AQI  \
# 34112       Colorado       Adams           8            1  2018-01-01   71
# 214548          Ohio       Adams          39            1  2018-01-01   36
# 242676  Pennsylvania       Adams          42            1  2018-01-01   35
# 309133    Washington       Adams          53            1  2018-01-01   26
#
#         Category Defining Parameter Defining Site  Number of Sites Reporting
# 34112   Moderate              PM2.5   08-001-0008                          2
# 214548      Good              PM2.5   39-001-0001                          1
# 242676      Good              Ozone   42-001-0001                          2
# 309133      Good              PM2.5   53-001-0003                          1

# %%
data["State Name"].nunique()
# Out:
# 53

# %%
data["county Name"].nunique()
# Out:
# 809

# %%
data[data["State Name"] == "Alabama"]["Date"].nunique()
# Out:
# 365

# %%
data.groupby("state_county")["Date"].count().describe()
# Out:
# count    1050.000000
# mean      323.313333
# std        77.527595
# min         8.000000
# 25%       325.000000
# 50%       362.000000
# 75%       365.000000
# max       365.000000
# Name: Date, dtype: float64

# %%
data.groupby("county Name")["Date"].nunique().head()
# Out:
# county Name
# Ada         365
# Adair       365
# Adams       365
# Adjuntas     27
# Aiken       228
# Name: Date, dtype: int64

# %%
data.groupby("State Name")["Date"].nunique().head()
# Out:
# State Name
# Alabama       365
# Alaska        365
# Arizona       365
# Arkansas      365
# California    365
# Name: Date, dtype: int64

# %%
data.isnull().sum()
# Out:
# State Name                   0
# county Name                  0
# State Code                   0
# County Code                  0
# Date                         0
# AQI                          0
# Category                     0
# Defining Parameter           0
# Defining Site                0
# Number of Sites Reporting    0
# dtype: int64
